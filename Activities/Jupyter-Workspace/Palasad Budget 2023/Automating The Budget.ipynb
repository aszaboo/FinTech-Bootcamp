# %%
# downloading imports
import pandas as pd
import numpy as np
import datetime as dt
# !ls
# Out:
# Automating The Budget.ipynb
# Palasad Budget 2023 220303 v2.xlsm - Data - North.csv

# %%
# Reading whale returns
north_sales_and_labour = pd.read_csv("Palasad Budget 2023 220303 v2.xlsm - Data - North.csv",parse_dates=True,infer_datetime_format=True)
north_sales_and_labour.
north_sales_and_labour
# Out:
#                          Palasad Billiards North Unnamed: 1 Unnamed: 2  \
# 0    Bi-Weekly Sales & Direct Labour Cost Report        NaN        NaN
# 1                                            NaN        NaN        NaN
# 2                                            NaN        NaN        NaN
# 3                                            NaN       2014       2014
# 4                                            NaN     14-Jun     28-Jun
# ..                                           ...        ...        ...
# 365                                          NaN        NaN        NaN
# 366                                          NaN        NaN        NaN
# 367                                          NaN        NaN        NaN
# 368                                          NaN        NaN        NaN
# 369                                          NaN        NaN        NaN
#
#     Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# ...

# %%
north_sales_and_labour = north_sales_and_labour.dropna(subset=['Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5'], how='all')
north_sales_and_labour.head()
# Out:
#     Palasad Billiards North Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 3                       NaN       2014       2014       2014       2014
# 4                       NaN     14-Jun     28-Jun     12-Jul     26-Jul
# 7               Food (4500)    39,482     37,258     32,889     37,412
# 8         Draft Beer (4575)    10,090     11,427      9,342     11,503
# 9       Bottled Beer (4565)     4,807      2,301      4,114      1,865
# ..                      ...        ...        ...        ...        ...
# 320                   Hours       149        142        120        125
# 322                Earnings     1,618      1,549      1,472      1,338
# 324                     NaN     10.89      10.90      12.23      10.73
# 325     Total Direct Labour    20,124     19,392     20,401     18,266
# 326                Variance    - 0.00        -       - 0.00        -
#
#     Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 199  \
# ...

# %%
north_sales_and_labour = north_sales_and_labour.iloc[3:]
north_sales_and_labour['Dates'] = north_sales_and_labour.iloc[4] + north_sales_and_labour.iloc[3]
# Out:
# /opt/anaconda3/envs/masterenv/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# Out:
#            Palasad Billiards North Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 3                              NaN       2014       2014       2014
# 4                              NaN     14-Jun     28-Jun     12-Jul
# 5                              NaN        NaN        NaN        NaN
# 6    Sales (Sales by Account Code)        NaN        NaN        NaN
# 7                      Food (4500)    39,482     37,258     32,889
# ..                             ...        ...        ...        ...
# 365                            NaN        NaN        NaN        NaN
# 366                            NaN        NaN        NaN        NaN
# 367                            NaN        NaN        NaN        NaN
# 368                            NaN        NaN        NaN        NaN
# 369                            NaN        NaN        NaN        NaN
#
#     Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ...  \
# ...
