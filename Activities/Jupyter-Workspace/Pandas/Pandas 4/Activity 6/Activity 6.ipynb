# %%
import pandas as pd
# !ls
# Out:
# Activity 6.ipynb    people_cleansed.csv

# %%
people_cleansed = pd.read_csv("people_cleansed.csv")

# %%
people_cleansed.head()
# Out:
#    Person_ID    Last_Name First_Name  Gender  \
# 0          1    Lenormand    Keriann  Female
# 1          2        Rupke    Huntley    Male
# 2          3  Dalgarnowch     Gorden    Male
# 3          4      Unnamed     Cullie    Male
# 4          5    Strangman      Ariel  Female
#
#                                           University          Occupation  \
# 0                                  Aurora University  Nurse Practicioner
# 1                      Osaka University of Economics     Project Manager
# 2                                  Ludong University  Environmental Tech
# 3  Université des Sciences et de la Technologie d...     Legal Assistant
# 4                             Boise State University     Project Manager
#
#     Salary                            Email  Age
# 0  58135.0  klenormand0@businessinsider.com   27
# 1  96053.0              hrupke1@reuters.com   22
# 2  59196.0      gdalgarnowch2@microsoft.com   40
# 3  88493.0               cputten3@nymag.com   62
# ...

# %%
occupation_sum = people_cleansed.groupby(['Occupation']).sum()
occupation_sum
# Out:
#                             Person_ID    Salary  Age
# Occupation
# Account Coordinator              1965  549150.0  316
# Account Executive                 560  319611.0  191
# Account Representative I          774   75871.0   63
# Account Representative II        2527  361567.0  208
# Account Representative III       1787  365999.0  158
# ...                               ...       ...  ...
# Web Designer III                  577   78667.0   30
# Web Developer I                  1496  198877.0   92
# Web Developer II                  801   75447.0   58
# Web Developer III                 906  261044.0  124
# Web Developer IV                 1741  307261.0  138
#
# [183 rows x 3 columns]

# %%
occupation_sum.groupby(['Salary','Age']).mean()
# Out:
#                Person_ID
# Salary    Age
# 50525.0   58       373.0
# 50815.0   57       826.0
# 55366.0   47       601.0
# 56177.0   62       248.0
# 67890.0   53       698.0
# ...                  ...
# 1165910.0 537     5587.0
# 1208283.0 496     7714.0
# 1234356.0 723     7832.0
# 1295038.0 635     8205.0
# 1346559.0 686     7948.0
#
# [183 rows x 1 columns]
