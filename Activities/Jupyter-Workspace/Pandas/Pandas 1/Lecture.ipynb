# %%
# Pandas - excel on sterioids
# Allows for # of rows to become much larger, machiene learning, third pary libraries
# Connects to APIs
# Automates processes

# %%
import pandas as pd

# %%
df=pd.read_csv("sales.csv")

# %%
df
# Out:
#              FullName                      Email                   Address  \
# 0       Elwanda White         alyre2036@live.com        352 Lakeshore Mall
# 1      Lyndon Elliott     arrowy1873@outlook.com          1234 Avery Plaza
# 2      Daisey Sellers     toucan2024@outlook.com         469 Elwood Street
# 3        Issac Reeves       asarin1958@gmail.com          565 Phelps Field
# 4     Bradford Kinney     mibound1801@yandex.com  853 Mission Rock Freeway
# ..                ...                        ...                       ...
# 95         Basil Rios       holloo1814@yahoo.com         605 Sloat Terrace
# 96      Hipolito Rios  calefacient2049@gmail.com   1248 Fountain Boulevard
# 97  Clayton Robertson         coner2015@live.com         230 Paper Parkway
# 98      Tony Chandler     sexillion2061@live.com      118 Flood Plantation
# 99        Cuc Mcgowan   dispatched1820@gmail.com        87 Louisiana Grove
#
#       Zip           CreditCard  SalePrice
# ...

# %%
df.head()
# Out:
#           FullName                   Email                   Address    Zip  \
# 0    Elwanda White      alyre2036@live.com        352 Lakeshore Mall   9236
# 1   Lyndon Elliott  arrowy1873@outlook.com          1234 Avery Plaza   1330
# 2   Daisey Sellers  toucan2024@outlook.com         469 Elwood Street   7631
# 3     Issac Reeves    asarin1958@gmail.com          565 Phelps Field  81168
# 4  Bradford Kinney  mibound1801@yandex.com  853 Mission Rock Freeway  41721
#
#             CreditCard  SalePrice
# 0  5327 0855 9720 7055      84.33
# 1    3717 498777 19636     879.95
# 2    3758 579477 35734     907.58
# 3  4400 0380 4162 1622     545.88
# 4    3712 263405 60178     517.49

# %%
df.head(10)
# Out:
#           FullName                      Email                   Address  \
# 0    Elwanda White         alyre2036@live.com        352 Lakeshore Mall
# 1   Lyndon Elliott     arrowy1873@outlook.com          1234 Avery Plaza
# 2   Daisey Sellers     toucan2024@outlook.com         469 Elwood Street
# 3     Issac Reeves       asarin1958@gmail.com          565 Phelps Field
# 4  Bradford Kinney     mibound1801@yandex.com  853 Mission Rock Freeway
# 5     Fermina Cobb    kingfisher2013@live.com          929 Prague Trail
# 6  Merrill Andrews        beechy2059@live.com          41 Clarion Drive
# 7   Claris Pearson     kiwifruit2045@live.com          638 Lundeen Park
# 8  Georgiann Black  tattooage1863@outlook.com    1139 San Lorenzo Green
# 9     Carlos Hicks    lengthen1993@yandex.com       1218 Angelos Parade
#
#      Zip           CreditCard  SalePrice
# 0   9236  5327 0855 9720 7055      84.33
# 1   1330    3717 498777 19636     879.95
# 2   7631    3758 579477 35734     907.58
# ...

# %%
# shows # of rows, # number of columns
df.shape
# Out:
# (100, 6)

# %%
# takes all numberical values and does stuff with them
df.describe()
# Out:
#                 Zip   SalePrice
# count    100.000000  100.000000
# mean   40952.160000  533.007200
# std    30207.118496  275.531072
# min      555.000000   29.720000
# 25%    11109.750000  328.507500
# 50%    40033.500000  536.110000
# 75%    65834.750000  767.885000
# max    99877.000000  998.760000

# %%
# shows data frame object
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.columns
# Out:
# Index(['FullName', 'Email', 'Address', 'Zip', 'CreditCard', 'SalePrice'], dtype='object')

# %%
df['SalePrice']
# Out:
# 0      84.33
# 1     879.95
# 2     907.58
# 3     545.88
# 4     517.49
#        ...
# 95    937.14
# 96    645.82
# 97    128.73
# 98    820.00
# 99    764.69
# Name: SalePrice, Length: 100, dtype: float64

# %%
type(df['SalePrice'])
# Out:
# pandas.core.series.Series

# %%
df[['SalePrice']]
# Out:
#     SalePrice
# 0       84.33
# 1      879.95
# 2      907.58
# 3      545.88
# 4      517.49
# ..        ...
# 95     937.14
# 96     645.82
# 97     128.73
# 98     820.00
# 99     764.69
#
# [100 rows x 1 columns]

# %%
df['SalePricewithTax'] = df[['SalePrice']]*1.13

# %%
df.head()
# Out:
#           FullName                   Email                   Address    Zip  \
# 0    Elwanda White      alyre2036@live.com        352 Lakeshore Mall   9236
# 1   Lyndon Elliott  arrowy1873@outlook.com          1234 Avery Plaza   1330
# 2   Daisey Sellers  toucan2024@outlook.com         469 Elwood Street   7631
# 3     Issac Reeves    asarin1958@gmail.com          565 Phelps Field  81168
# 4  Bradford Kinney  mibound1801@yandex.com  853 Mission Rock Freeway  41721
#
#             CreditCard  SalePrice  SalePricewithTax
# 0  5327 0855 9720 7055      84.33           95.2929
# 1    3717 498777 19636     879.95          994.3435
# 2    3758 579477 35734     907.58         1025.5654
# 3  4400 0380 4162 1622     545.88          616.8444
# 4    3712 263405 60178     517.49          584.7637

# %%
df['CreditCardNum'] = df['CreditCard'].astype
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/4v/cn7thfts6hjfkp7gdl9lkpxr0000gn/T/ipykernel_40612/1903069624.py in <module>
# ----> 1 df['CreditCardNum'] = df['CreditCard'].astype(int)
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5918         else:
#    5919             # else, only a single dtype is given
# -> 5920             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5921             return self._constructor(new_data).__finalize__(self, method="astype")
#    5922
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     417
#     418     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 419         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
# ...

# %%
df['CreditCard'].str.replace(' ','').astype(int)
# Out:
# 0     5327085597207055
# 1      371749877719636
# 2      375857947735734
# 3     4400038041621622
# 4      371226340560178
#             ...
# 95    5581724584519384
# 96    2333026453432022
# 97    2414393965012607
# 98    5581805918831841
# 99    2678414055313894
# Name: CreditCard, Length: 100, dtype: int64

# %%
df['CreditCardNum'] = df['CreditCard'].str.replace(' ','').astype(int)

# %%
df
# Out:
#              FullName                      Email                   Address  \
# 0       Elwanda White         alyre2036@live.com        352 Lakeshore Mall
# 1      Lyndon Elliott     arrowy1873@outlook.com          1234 Avery Plaza
# 2      Daisey Sellers     toucan2024@outlook.com         469 Elwood Street
# 3        Issac Reeves       asarin1958@gmail.com          565 Phelps Field
# 4     Bradford Kinney     mibound1801@yandex.com  853 Mission Rock Freeway
# ..                ...                        ...                       ...
# 95         Basil Rios       holloo1814@yahoo.com         605 Sloat Terrace
# 96      Hipolito Rios  calefacient2049@gmail.com   1248 Fountain Boulevard
# 97  Clayton Robertson         coner2015@live.com         230 Paper Parkway
# 98      Tony Chandler     sexillion2061@live.com      118 Flood Plantation
# 99        Cuc Mcgowan   dispatched1820@gmail.com        87 Louisiana Grove
#
#       Zip           CreditCard  SalePrice  SalePricewithTax  \
# ...

# %%
df.dtypes
# Out:
# FullName             object
# Email                object
# Address              object
# Zip                   int64
# CreditCard           object
# SalePrice           float64
# SalePricewithTax    float64
# CreditCardNum         int64
# dtype: object

# %%
df.drop(columns=['CreditCard'])
# Out:
#              FullName                      Email                   Address  \
# 0       Elwanda White         alyre2036@live.com        352 Lakeshore Mall
# 1      Lyndon Elliott     arrowy1873@outlook.com          1234 Avery Plaza
# 2      Daisey Sellers     toucan2024@outlook.com         469 Elwood Street
# 3        Issac Reeves       asarin1958@gmail.com          565 Phelps Field
# 4     Bradford Kinney     mibound1801@yandex.com  853 Mission Rock Freeway
# ..                ...                        ...                       ...
# 95         Basil Rios       holloo1814@yahoo.com         605 Sloat Terrace
# 96      Hipolito Rios  calefacient2049@gmail.com   1248 Fountain Boulevard
# 97  Clayton Robertson         coner2015@live.com         230 Paper Parkway
# 98      Tony Chandler     sexillion2061@live.com      118 Flood Plantation
# 99        Cuc Mcgowan   dispatched1820@gmail.com        87 Louisiana Grove
#
#       Zip  SalePrice  SalePricewithTax     CreditCardNum
# ...

# %%
df.head()
# Out:
#           FullName                   Email                   Address    Zip  \
# 0    Elwanda White      alyre2036@live.com        352 Lakeshore Mall   9236
# 1   Lyndon Elliott  arrowy1873@outlook.com          1234 Avery Plaza   1330
# 2   Daisey Sellers  toucan2024@outlook.com         469 Elwood Street   7631
# 3     Issac Reeves    asarin1958@gmail.com          565 Phelps Field  81168
# 4  Bradford Kinney  mibound1801@yandex.com  853 Mission Rock Freeway  41721
#
#             CreditCard  SalePrice  SalePricewithTax     CreditCardNum
# 0  5327 0855 9720 7055      84.33           95.2929  5327085597207055
# 1    3717 498777 19636     879.95          994.3435   371749877719636
# 2    3758 579477 35734     907.58         1025.5654   375857947735734
# 3  4400 0380 4162 1622     545.88          616.8444  4400038041621622
# 4    3712 263405 60178     517.49          584.7637   371226340560178

# %%
df.drop(columns=['CreditCard'], inplace=True)

# %%
df.head()
# Out:
#           FullName                   Email                   Address    Zip  \
# 0    Elwanda White      alyre2036@live.com        352 Lakeshore Mall   9236
# 1   Lyndon Elliott  arrowy1873@outlook.com          1234 Avery Plaza   1330
# 2   Daisey Sellers  toucan2024@outlook.com         469 Elwood Street   7631
# 3     Issac Reeves    asarin1958@gmail.com          565 Phelps Field  81168
# 4  Bradford Kinney  mibound1801@yandex.com  853 Mission Rock Freeway  41721
#
#    SalePrice  SalePricewithTax     CreditCardNum
# 0      84.33           95.2929  5327085597207055
# 1     879.95          994.3435   371749877719636
# 2     907.58         1025.5654   375857947735734
# 3     545.88          616.8444  4400038041621622
# 4     517.49          584.7637   371226340560178

# %%
df.columns
# Out:
# Index(['FullName', 'Email', 'Address', 'Zip', 'SalePrice', 'SalePricewithTax',
#        'CreditCardNum'],
#       dtype='object')

# %%
df[['Email', 'FullName','Address', 'Zip', 'SalePrice', 'SalePricewithTax',
       'CreditCardNum']]
# Out:
#                         Email           FullName                   Address  \
# 0          alyre2036@live.com      Elwanda White        352 Lakeshore Mall
# 1      arrowy1873@outlook.com     Lyndon Elliott          1234 Avery Plaza
# 2      toucan2024@outlook.com     Daisey Sellers         469 Elwood Street
# 3        asarin1958@gmail.com       Issac Reeves          565 Phelps Field
# 4      mibound1801@yandex.com    Bradford Kinney  853 Mission Rock Freeway
# ..                        ...                ...                       ...
# 95       holloo1814@yahoo.com         Basil Rios         605 Sloat Terrace
# 96  calefacient2049@gmail.com      Hipolito Rios   1248 Fountain Boulevard
# 97         coner2015@live.com  Clayton Robertson         230 Paper Parkway
# 98     sexillion2061@live.com      Tony Chandler      118 Flood Plantation
# 99   dispatched1820@gmail.com        Cuc Mcgowan        87 Louisiana Grove
#
#       Zip  SalePrice  SalePricewithTax     CreditCardNum
# ...

# %%
df.rename(columns={"FullName": "Full_Name","CreditCardNum": "Credit_Card_N"},inplace=True)
# Out:
#   File "/var/folders/4v/cn7thfts6hjfkp7gdl9lkpxr0000gn/T/ipykernel_40612/4279245442.py", line 1
#     df.rename={"FullName": "Full_Name","CreditCardNum": "Credit_Card_N"},inplace=True
#               ^
# SyntaxError: cannot assign to dict display

# %%
df['Zip'].value_counts()
# Out:
# 9236     1
# 37881    1
# 1771     1
# 81524    1
# 24627    1
#         ..
# 49688    1
# 27711    1
# 75745    1
# 61738    1
# 70959    1
# Name: Zip, Length: 100, dtype: int64

# %%
df[['Zip']].value_counts()
# Out:
# Zip
# 555      1
# 51278    1
# 65278    1
# 62764    1
# 61803    1
#         ..
# 16625    1
# 14344    1
# 13487    1
# 11767    1
# 99877    1
# Length: 100, dtype: int64

# %%
df['Zip'].isnull()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 95    False
# 96    False
# 97    False
# 98    False
# 99    False
# Name: Zip, Length: 100, dtype: bool

# %%
df['Zip'].isnull().mean()
# Out:
# 0.0

# %%
df['Zip'].isnull().sum()
# Out:
# 0
